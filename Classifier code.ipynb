# %% [markdown]
# #Prepreocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/AI Lab/drug.csv')

# %%
df.head()
# Out:
#          Timestamp   Age Gender Education (last/ongoing)  \
# 0  8/15/2023 22:23  21.0   Male            Undergraduate
# 1  8/15/2023 22:27  22.0   Male            Undergraduate
# 2  8/15/2023 22:29  21.0   Male            Undergraduate
# 3  8/15/2023 22:32  22.0   Male            Undergraduate
# 4  8/15/2023 22:32  23.0   Male            Undergraduate
#
#   With whom do you live? What is your thinking about drug?  \
# 0                 Family             Disease, should avoid
# 1            Hall/Hostel                      Should avoid
# 2                 Family             Disease, should avoid
# 3                 Family                      Should avoid
# 4            Hall/Hostel        Social trend, should avoid
#
#   With whom do you spend most of your times? Did you ever fail in your life?  \
# 0                           Family/Relatives                             Yes
# 1                                      Alone                             Yes
# 2                           Family/Relatives                             Yes
# 3                                    Friends                             Yes
# 4                                      Alone                              No
#
#   Do you get suicidal thoughts? How is your family relationship?  ...  \
# 0                            No                        Very good  ...
# 1                            No                     Satisfactory  ...
# 2                            No                        Very good  ...
# 3                           Yes                        Very good  ...
# 4                            No                        Very good  ...
#
#   Have you ever taken drug?  \
# 0                        No
# 1                        No
# 2                        No
# 3                        No
# 4                        No
#
#   What is the name of the drug you used for the 1st time?  \
# 0                                        Never taken
# 1                                        Never taken
# 2                                        Never taken
# 3                                        Never taken
# 4                                        Never taken
#
#   At what age you used drugs for the 1st time? How often do you use drugs?  \
# 0                                           No                No, I do not
# 1                                        Never                No, I do not
# 2                                           No                No, I do not
# 3                                          NaN                No, I do not
# 4                                          NaN                No, I do not
#
#   What drug do you use currently? In what occasions do you use drugs?  \
# 0                         No drug                          Do not use
# 1                         No drug                          Do not use
# 2                         No drug                          Do not use
# 3                         No drug                          Do not use
# 4                         No drug                          Do not use
#
#   If you have a chance, will you taste drug?  \
# 0                                         No
# 1                                         No
# 2                                         No
# 3                                         No
# 4                                         No
#
#   Is it easy to control the use of drug?  \
# 0                                    Yes
# 1                                     No
# 2                                    Yes
# 3                                    Yes
# 4                                    Yes
#
#                       Why did you start using drugs?  \
# 0                                Teenagers curiosity
# 1                                                NaN
# 2  Teenagers curiosity, Failure in love, Emotiona...
# 3                                                NaN
# 4                                                NaN
#
#   Do you feel guilty after taking drugs?
# 0                                    NaN
# 1                                    NaN
# 2                                    Yes
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 27 columns]

# %%
# Assuming 'df' is your DataFrame with the original column names
# Replace 'df' with your actual DataFrame name

new_column_names = {
    'Age': 'Age',
    'Gender': 'Gender',
    'Education (last/ongoing)': 'Education',
    'With whom do you live?': 'Living Situation',
    'What is your thinking about drug?': 'Attitude Towards Drugs',
    'With whom do you spend most of your times?': 'Social Connections',
    'Did you ever fail in your life?': 'Past Failures',
    'Do you get suicidal thoughts?': 'Suicidal Thoughts',
    'How is your family relationship?': 'Family Relationships',
    'What is the financial condition of your family?': 'Family Finances',
    'How many addicted friends do you have?': 'Addicted Friends',
    'Do you have any addicted person in your family?': 'Family Addiction',
    'Are you satisfied with your workplace?': 'Workplace Satisfaction',
    'Do you have any case running at court or police station?': 'Legal Cases',
    'Do you live with any drug user?': 'Living with Drug User',
    'What can be the factors for using drug?': 'Drug Use Factors',
    'Have you ever taken drug?': 'Past Drug Use',
    'What is the name of the drug you used for the 1st time?': 'First Drug Name',
    'At what age you used drugs for the 1st time?': 'First Drug Age',
    'How often do you use drugs?': 'Frequency of Drug Use',
    'What drug do you use currently?': 'Current Drug Use',
    'In what occasions do you use drugs?': 'Occasions for Drug Use',
    'If you have a chance, will you taste drug?': 'Willingness to Try Drugs',
    'Is it easy to control the use of drug?': 'Drug Control',
    'Why did you start using drugs?': 'Reasons for Starting',
    'Do you feel guilty after taking drugs?': 'Guilt After Drug Use'
}

# Rename the columns
df.rename(columns=new_column_names, inplace=True)

# Now your DataFrame 'df' will have the updated column names
df.head()
# Out:
#          Timestamp   Age Gender      Education Living Situation  \
# 0  8/15/2023 22:23  21.0   Male  Undergraduate           Family
# 1  8/15/2023 22:27  22.0   Male  Undergraduate      Hall/Hostel
# 2  8/15/2023 22:29  21.0   Male  Undergraduate           Family
# 3  8/15/2023 22:32  22.0   Male  Undergraduate           Family
# 4  8/15/2023 22:32  23.0   Male  Undergraduate      Hall/Hostel
#
#        Attitude Towards Drugs Social Connections Past Failures  \
# 0       Disease, should avoid   Family/Relatives           Yes
# 1                Should avoid              Alone           Yes
# 2       Disease, should avoid   Family/Relatives           Yes
# 3                Should avoid            Friends           Yes
# 4  Social trend, should avoid              Alone            No
#
#   Suicidal Thoughts Family Relationships  ... Past Drug Use First Drug Name  \
# 0                No            Very good  ...            No     Never taken
# 1                No         Satisfactory  ...            No     Never taken
# 2                No            Very good  ...            No     Never taken
# 3               Yes            Very good  ...            No     Never taken
# 4                No            Very good  ...            No     Never taken
#
#   First Drug Age Frequency of Drug Use Current Drug Use  \
# 0             No          No, I do not          No drug
# 1          Never          No, I do not          No drug
# 2             No          No, I do not          No drug
# 3            NaN          No, I do not          No drug
# 4            NaN          No, I do not          No drug
#
#   Occasions for Drug Use Willingness to Try Drugs Drug Control  \
# 0             Do not use                       No          Yes
# 1             Do not use                       No           No
# 2             Do not use                       No          Yes
# 3             Do not use                       No          Yes
# 4             Do not use                       No          Yes
#
#                                 Reasons for Starting Guilt After Drug Use
# 0                                Teenagers curiosity                  NaN
# 1                                                NaN                  NaN
# 2  Teenagers curiosity, Failure in love, Emotiona...                  Yes
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                          3
# Gender                       0
# Education                    1
# Living Situation             0
# Attitude Towards Drugs       0
# Social Connections           0
# Past Failures                1
# Suicidal Thoughts            0
# Family Relationships         1
# Family Finances              0
# Addicted Friends             1
# Family Addiction             1
# Workplace Satisfaction       3
# Legal Cases                  1
# Living with Drug User        1
# Drug Use Factors             5
# Past Drug Use                2
# First Drug Name             15
# First Drug Age              26
# Frequency of Drug Use       12
# Current Drug Use            13
# Occasions for Drug Use      13
# Willingness to Try Drugs     5
# Drug Control                 9
# Reasons for Starting        40
# Guilt After Drug Use        29
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
import math
modeTestScore1=(df['Age'].mode()[0])
modeTestScore2=(df['Education'].mode()[0])
modeTestScore3=(df['Past Failures'].mode()[0])
modeTestScore4=(df['Family Relationships'].mode()[0])
modeTestScore5=(df['Addicted Friends'].mode()[0])
modeTestScore6=(df['Family Addiction'].mode()[0])
modeTestScore7=(df['Workplace Satisfaction'].mode()[0])
modeTestScore8=(df['Legal Cases'].mode()[0])
modeTestScore9=(df['Living with Drug User'].mode()[0])
modeTestScore10=(df['Drug Use Factors'].mode()[0])
modeTestScore11=(df['Past Drug Use'].mode()[0])
modeTestScore12=(df['First Drug Name'].mode()[0])
modeTestScore13=(df['First Drug Age'].mode()[0])
modeTestScore14=(df['Frequency of Drug Use'].mode()[0])
modeTestScore15=(df['Current Drug Use'].mode()[0])
modeTestScore16=(df['Occasions for Drug Use'].mode()[0])
modeTestScore17=(df['Willingness to Try Drugs'].mode()[0])
modeTestScore18=(df['Drug Control'].mode()[0])
modeTestScore19=(df['Reasons for Starting'].mode()[0])
modeTestScore20=(df['Guilt After Drug Use'].mode()[0])


df['Age']=df['Age'].fillna(modeTestScore1)
df['Education']=df['Education'].fillna(modeTestScore2)
df['Past Failures']=df['Past Failures'].fillna(modeTestScore3)
df['Family Relationships']=df['Family Relationships'].fillna(modeTestScore4)
df['Addicted Friends']=df['Addicted Friends'].fillna(modeTestScore5)
df['Family Addiction']=df['Family Addiction'].fillna(modeTestScore6)
df['Workplace Satisfaction']=df['Workplace Satisfaction'].fillna(modeTestScore7)
df['Legal Cases']=df['Legal Cases'].fillna(modeTestScore8)
df['Living with Drug User']=df['Living with Drug User'].fillna(modeTestScore9)
df['Drug Use Factors']=df['Drug Use Factors'].fillna(modeTestScore10)
df['Past Drug Use']=df['Past Drug Use'].fillna(modeTestScore11)
df['First Drug Name']=df['First Drug Name'].fillna(modeTestScore12)
df['First Drug Age']=df['First Drug Age'].fillna(modeTestScore13)
df['Frequency of Drug Use']=df['Frequency of Drug Use'].fillna(modeTestScore14)
df['Current Drug Use']=df['Current Drug Use'].fillna(modeTestScore15)
df['Occasions for Drug Use']=df['Occasions for Drug Use'].fillna(modeTestScore16)
df['Willingness to Try Drugs']=df['Willingness to Try Drugs'].fillna(modeTestScore17)
df['Drug Control']=df['Drug Control'].fillna(modeTestScore18)
df['Reasons for Starting']=df['Reasons for Starting'].fillna(modeTestScore19)
df['Guilt After Drug Use']=df['Guilt After Drug Use'].fillna(modeTestScore20)

# %%
df.isnull().sum()
# Out:
# Timestamp                   0
# Age                         0
# Gender                      0
# Education                   0
# Living Situation            0
# Attitude Towards Drugs      0
# Social Connections          0
# Past Failures               0
# Suicidal Thoughts           0
# Family Relationships        0
# Family Finances             0
# Addicted Friends            0
# Family Addiction            0
# Workplace Satisfaction      0
# Legal Cases                 0
# Living with Drug User       0
# Drug Use Factors            0
# Past Drug Use               0
# First Drug Name             0
# First Drug Age              0
# Frequency of Drug Use       0
# Current Drug Use            0
# Occasions for Drug Use      0
# Willingness to Try Drugs    0
# Drug Control                0
# Reasons for Starting        0
# Guilt After Drug Use        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your DataFrame
# Replace 'df' with your actual DataFrame name

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# List of columns to label encode (adjust as needed)
categorical_columns = [
    'Gender', 'Education', 'Living Situation', 'Attitude Towards Drugs',
    'Social Connections', 'Past Failures', 'Suicidal Thoughts',
    'Family Relationships', 'Family Finances', 'Addicted Friends',
    'Family Addiction', 'Workplace Satisfaction', 'Legal Cases',
    'Living with Drug User', 'Drug Use Factors', 'Past Drug Use',
    'First Drug Name', 'First Drug Age', 'Frequency of Drug Use',
    'Current Drug Use', 'Occasions for Drug Use', 'Willingness to Try Drugs',
    'Drug Control', 'Reasons for Starting', 'Guilt After Drug Use'
]

# Apply label encoding to categorical columns
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Now, categorical values are converted to numeric
df.head()
# Out:
#          Timestamp   Age  Gender  Education  Living Situation  \
# 0  8/15/2023 22:23  21.0       1          3                 1
# 1  8/15/2023 22:27  22.0       1          3                 3
# 2  8/15/2023 22:29  21.0       1          3                 1
# 3  8/15/2023 22:32  22.0       1          3                 1
# 4  8/15/2023 22:32  23.0       1          3                 3
#
#    Attitude Towards Drugs  Social Connections  Past Failures  \
# 0                       0                   1              1
# 1                       2                   0              1
# 2                       0                   1              1
# 3                       2                   2              1
# 4                       4                   0              0
#
#    Suicidal Thoughts  Family Relationships  ...  Past Drug Use  \
# 0                  0                     3  ...              0
# 1                  0                     2  ...              0
# 2                  0                     3  ...              0
# 3                  1                     3  ...              0
# 4                  0                     3  ...              0
#
#    First Drug Name  First Drug Age  Frequency of Drug Use  Current Drug Use  \
# 0                3              15                      1                 5
# 1                3              11                      1                 5
# 2                3              15                      1                 5
# 3                3               3                      1                 5
# 4                3               3                      1                 5
#
#    Occasions for Drug Use  Willingness to Try Drugs  Drug Control  \
# 0                       6                         1             1
# 1                       6                         1             0
# 2                       6                         1             1
# 3                       6                         1             1
# 4                       6                         1             1
#
#    Reasons for Starting  Guilt After Drug Use
# 0                    11                     2
# 1                     1                     2
# 2                    12                     2
# 3                     1                     2
# 4                     1                     2
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Timestamp                 69 non-null     object
#  1   Age                       69 non-null     float64
#  2   Gender                    69 non-null     int64
#  3   Education                 69 non-null     int64
#  4   Living Situation          69 non-null     int64
#  5   Attitude Towards Drugs    69 non-null     int64
#  6   Social Connections        69 non-null     int64
#  7   Past Failures             69 non-null     int64
#  8   Suicidal Thoughts         69 non-null     int64
#  9   Family Relationships      69 non-null     int64
#  10  Family Finances           69 non-null     int64
#  11  Addicted Friends          69 non-null     int64
#  12  Family Addiction          69 non-null     int64
#  13  Workplace Satisfaction    69 non-null     int64
#  14  Legal Cases               69 non-null     int64
#  15  Living with Drug User     69 non-null     int64
#  16  Drug Use Factors          69 non-null     int64
#  17  Past Drug Use             69 non-null     int64
#  18  First Drug Name           69 non-null     int64
#  19  First Drug Age            69 non-null     int64
#  20  Frequency of Drug Use     69 non-null     int64
#  21  Current Drug Use          69 non-null     int64
#  22  Occasions for Drug Use    69 non-null     int64
#  23  Willingness to Try Drugs  69 non-null     int64
#  24  Drug Control              69 non-null     int64
#  25  Reasons for Starting      69 non-null     int64
#  26  Guilt After Drug Use      69 non-null     int64
# dtypes: float64(1), int64(25), object(1)
# memory usage: 14.7+ KB

# %%
df.describe()
# Out:
#              Age     Gender  Education  Living Situation  \
# count  69.000000  69.000000  69.000000         69.000000
# mean   22.188406   0.840580   2.782609          1.840580
# std     1.872992   0.406679   0.704389          1.051934
# min    15.000000   0.000000   0.000000          0.000000
# 25%    22.000000   1.000000   3.000000          1.000000
# 50%    22.000000   1.000000   3.000000          1.000000
# 75%    23.000000   1.000000   3.000000          3.000000
# max    28.000000   2.000000   3.000000          4.000000
#
#        Attitude Towards Drugs  Social Connections  Past Failures  \
# count               69.000000           69.000000      69.000000
# mean                 2.130435            1.014493       0.797101
# std                  1.327459            0.795072       0.405104
# min                  0.000000            0.000000       0.000000
# 25%                  2.000000            0.000000       1.000000
# 50%                  2.000000            1.000000       1.000000
# 75%                  3.000000            2.000000       1.000000
# max                  4.000000            2.000000       1.000000
#
#        Suicidal Thoughts  Family Relationships  Family Finances  ...  \
# count          69.000000             69.000000        69.000000  ...
# mean            0.275362              2.478261         0.173913  ...
# std             0.449969              0.901122         0.483751  ...
# min             0.000000              0.000000         0.000000  ...
# 25%             0.000000              2.000000         0.000000  ...
# 50%             0.000000              3.000000         0.000000  ...
# 75%             1.000000              3.000000         0.000000  ...
# max             1.000000              3.000000         2.000000  ...
#
#        Past Drug Use  First Drug Name  First Drug Age  Frequency of Drug Use  \
# count      69.000000        69.000000       69.000000              69.000000
# mean        0.260870         1.710145        5.391304               1.231884
# std         0.442326         1.086027        4.608871               0.876908
# min         0.000000         0.000000        0.000000               0.000000
# 25%         0.000000         1.000000        3.000000               1.000000
# 50%         0.000000         1.000000        3.000000               1.000000
# 75%         1.000000         3.000000        7.000000               1.000000
# max         1.000000         4.000000       18.000000               5.000000
#
#        Current Drug Use  Occasions for Drug Use  Willingness to Try Drugs  \
# count         69.000000               69.000000                 69.000000
# mean           3.449275                6.014493                  1.043478
# std            2.329707                2.061501                  0.498078
# min            0.000000                0.000000                  0.000000
# 25%            0.000000                6.000000                  1.000000
# 50%            5.000000                6.000000                  1.000000
# 75%            5.000000                6.000000                  1.000000
# max            7.000000                9.000000                  2.000000
#
#        Drug Control  Reasons for Starting  Guilt After Drug Use
# count     69.000000             69.000000             69.000000
# mean       0.608696              3.449275              1.681159
# std        0.491618              4.350579              0.629957
# min        0.000000              0.000000              0.000000
# 25%        0.000000              1.000000              2.000000
# 50%        1.000000              1.000000              2.000000
# 75%        1.000000              3.000000              2.000000
# max        1.000000             16.000000              2.000000
#
# [8 rows x 26 columns]

# %%
plt.figure(figsize=(8, 8))
sns.histplot(data=df, kde=True)
plt.title("Histogram of DataFrame")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, orient='h')
plt.title("Box Plot of DataFrame")
plt.show()

# %%
plt.figure(figsize=(20, 6))
ax = df.describe().loc[['mean', 'std', '25%', '50%', '75%', 'max']].plot(kind='bar', legend=False)
plt.title("Bar Plot of Mean, Std, Min, Max")
plt.ylabel("Values")

# Customize x-axis labels
ax.set_xticklabels(['Mean', 'Std', '25%', '50%', '75%', 'Max'], rotation=0)

plt.show()

# %%
df.shape
# Out:
# (69, 27)

# %%
df.corr()
# Out:
#                                Age    Gender  Education  Living Situation  \
# Age                       1.000000  0.233077   0.332460         -0.118882
# Gender                    0.233077  1.000000  -0.071425          0.111596
# Education                 0.332460 -0.071425   1.000000         -0.027613
# Living Situation         -0.118882  0.111596  -0.027613          1.000000
# Attitude Towards Drugs    0.155583 -0.178841   0.030771         -0.058609
# Social Connections        0.175894  0.189176   0.084484         -0.014780
# Past Failures             0.031741  0.157828  -0.105313          0.199054
# Suicidal Thoughts        -0.010115 -0.319123  -0.040346         -0.216579
# Family Relationships      0.224646  0.130855  -0.042307         -0.058008
# Family Finances           0.028227 -0.081251  -0.060045         -0.089209
# Addicted Friends         -0.084536 -0.284438  -0.029117         -0.002340
# Family Addiction         -0.088071 -0.059358   0.042838          0.109003
# Workplace Satisfaction    0.055115 -0.050767   0.175863         -0.166827
# Legal Cases              -0.280231  0.121862  -0.198278          0.047112
# Living with Drug User     0.206763  0.143002  -0.146360         -0.031412
# Drug Use Factors         -0.149083  0.028307  -0.157318          0.006980
# Past Drug Use             0.188311  0.152840  -0.004104          0.027483
# First Drug Name          -0.153498 -0.139459   0.127880         -0.118278
# First Drug Age           -0.001852  0.049464  -0.027770         -0.041542
# Frequency of Drug Use    -0.134435  0.146421   0.059003          0.279797
# Current Drug Use         -0.201674 -0.187160   0.114161         -0.030351
# Occasions for Drug Use   -0.000718  0.090502  -0.018053          0.034988
# Willingness to Try Drugs  0.054145 -0.037879  -0.014580         -0.014644
# Drug Control              0.256922 -0.095941   0.175407          0.161964
# Reasons for Starting      0.045406  0.223935   0.041937         -0.035533
# Guilt After Drug Use      0.076588 -0.143921   0.172910         -0.033448
#
#                           Attitude Towards Drugs  Social Connections  \
# Age                                     0.155583            0.175894
# Gender                                 -0.178841            0.189176
# Education                               0.030771            0.084484
# Living Situation                       -0.058609           -0.014780
# Attitude Towards Drugs                  1.000000           -0.057552
# Social Connections                     -0.057552            1.000000
# Past Failures                          -0.168836           -0.036394
# Suicidal Thoughts                       0.209805           -0.134636
# Family Relationships                   -0.052917            0.154390
# Family Finances                         0.078659            0.108056
# Addicted Friends                       -0.061801           -0.124853
# Family Addiction                       -0.083348            0.113857
# Workplace Satisfaction                 -0.023330            0.012984
# Legal Cases                             0.203637            0.059499
# Living with Drug User                   0.135910            0.165408
# Drug Use Factors                        0.238552            0.114179
# Past Drug Use                           0.241742            0.156355
# First Drug Name                        -0.218206            0.038999
# First Drug Age                         -0.087786           -0.202230
# Frequency of Drug Use                   0.062068            0.100572
# Current Drug Use                       -0.237967           -0.138535
# Occasions for Drug Use                 -0.081309            0.125481
# Willingness to Try Drugs                0.191474           -0.150156
# Drug Control                           -0.010777            0.014722
# Reasons for Starting                   -0.048492            0.104376
# Guilt After Drug Use                   -0.248493            0.038723
#
#                           Past Failures  Suicidal Thoughts  \
# Age                            0.031741          -0.010115
# Gender                         0.157828          -0.319123
# Education                     -0.105313          -0.040346
# Living Situation               0.199054          -0.216579
# Attitude Towards Drugs        -0.168836           0.209805
# Social Connections            -0.036394          -0.134636
# Past Failures                  1.000000           0.068983
# Suicidal Thoughts              0.068983           1.000000
# Family Relationships          -0.012261          -0.257030
# Family Finances                0.107668           0.114557
# Addicted Friends              -0.202513           0.127625
# Family Addiction               0.069521           0.017883
# Workplace Satisfaction        -0.127412          -0.114708
# Legal Cases                   -0.100093          -0.075094
# Living with Drug User         -0.042415           0.080778
# Drug Use Factors              -0.095768          -0.035555
# Past Drug Use                  0.135593           0.150986
# First Drug Name               -0.035364           0.015265
# First Drug Age                -0.090750          -0.187452
# Frequency of Drug Use          0.134391          -0.089663
# Current Drug Use              -0.135722           0.104704
# Occasions for Drug Use         0.003573           0.090755
# Willingness to Try Drugs       0.117247           0.077028
# Drug Control                   0.038526          -0.037575
# Reasons for Starting           0.077515           0.003484
# Guilt After Drug Use          -0.026725           0.003008
#
#                           Family Relationships  Family Finances  ...  \
# Age                                   0.224646         0.028227  ...
# Gender                                0.130855        -0.081251  ...
# Education                            -0.042307        -0.060045  ...
# Living Situation                     -0.058008        -0.089209  ...
# Attitude Towards Drugs               -0.052917         0.078659  ...
# Social Connections                    0.154390         0.108056  ...
# Past Failures                        -0.012261         0.107668  ...
# Suicidal Thoughts                    -0.257030         0.114557  ...
# Family Relationships                  1.000000         0.042536  ...
# Family Finances                       0.042536         1.000000  ...
# Addicted Friends                     -0.054625        -0.083099  ...
# Family Addiction                     -0.073669         0.141387  ...
# Workplace Satisfaction                0.171836        -0.256074  ...
# Legal Cases                          -0.049997        -0.004657  ...
# Living with Drug User                 0.008801         0.245902  ...
# Drug Use Factors                     -0.104263         0.047501  ...
# Past Drug Use                         0.051332         0.128489  ...
# First Drug Name                       0.098654         0.041379  ...
# First Drug Age                        0.099453        -0.044164  ...
# Frequency of Drug Use                -0.067968        -0.200465  ...
# Current Drug Use                     -0.166901        -0.044252  ...
# Occasions for Drug Use                0.019963        -0.194267  ...
# Willingness to Try Drugs             -0.014246         0.090224  ...
# Drug Control                          0.063505        -0.080656  ...
# Reasons for Starting                  0.094430         0.116053  ...
# Guilt After Drug Use                 -0.038296        -0.104906  ...
#
#                           Past Drug Use  First Drug Name  First Drug Age  \
# Age                            0.188311        -0.153498       -0.001852
# Gender                         0.152840        -0.139459        0.049464
# Education                     -0.004104         0.127880       -0.027770
# Living Situation               0.027483        -0.118278       -0.041542
# Attitude Towards Drugs         0.241742        -0.218206       -0.087786
# Social Connections             0.156355         0.038999       -0.202230
# Past Failures                  0.135593        -0.035364       -0.090750
# Suicidal Thoughts              0.150986         0.015265       -0.187452
# Family Relationships           0.051332         0.098654        0.099453
# Family Finances                0.128489         0.041379       -0.044164
# Addicted Friends              -0.114992         0.090648       -0.123000
# Family Addiction               0.022739         0.250061       -0.051940
# Workplace Satisfaction        -0.280056         0.095053        0.127669
# Legal Cases                    0.050928        -0.203274        0.232164
# Living with Drug User          0.197216         0.055375        0.147117
# Drug Use Factors               0.010759         0.098154        0.111810
# Past Drug Use                  1.000000        -0.238250       -0.245577
# First Drug Name               -0.238250         1.000000        0.084692
# First Drug Age                -0.245577         0.084692        1.000000
# Frequency of Drug Use          0.069233        -0.098245       -0.113748
# Current Drug Use              -0.529259         0.319593        0.058714
# Occasions for Drug Use        -0.117099         0.001904       -0.003701
# Willingness to Try Drugs       0.281511        -0.139478        0.094979
# Drug Control                  -0.064687        -0.022754        0.081553
# Reasons for Starting           0.549553         0.018630        0.042442
# Guilt After Drug Use          -0.330425         0.271337       -0.143804
#
#                           Frequency of Drug Use  Current Drug Use  \
# Age                                   -0.134435         -0.201674
# Gender                                 0.146421         -0.187160
# Education                              0.059003          0.114161
# Living Situation                       0.279797         -0.030351
# Attitude Towards Drugs                 0.062068         -0.237967
# Social Connections                     0.100572         -0.138535
# Past Failures                          0.134391         -0.135722
# Suicidal Thoughts                     -0.089663          0.104704
# Family Relationships                  -0.067968         -0.166901
# Family Finances                       -0.200465         -0.044252
# Addicted Friends                      -0.046777          0.323267
# Family Addiction                       0.121584          0.092392
# Workplace Satisfaction                -0.058860          0.177241
# Legal Cases                           -0.023120         -0.059950
# Living with Drug User                 -0.096464         -0.031203
# Drug Use Factors                      -0.169525         -0.026088
# Past Drug Use                          0.069233         -0.529259
# First Drug Name                       -0.098245          0.319593
# First Drug Age                        -0.113748          0.058714
# Frequency of Drug Use                  1.000000         -0.361276
# Current Drug Use                      -0.361276          1.000000
# Occasions for Drug Use                 0.307241          0.004748
# Willingness to Try Drugs              -0.090762          0.071632
# Drug Control                          -0.093438          0.040195
# Reasons for Starting                   0.014693         -0.381486
# Guilt After Drug Use                   0.082564          0.169183
#
#                           Occasions for Drug Use  Willingness to Try Drugs  \
# Age                                    -0.000718                  0.054145
# Gender                                  0.090502                 -0.037879
# Education                              -0.018053                 -0.014580
# Living Situation                        0.034988                 -0.014644
# Attitude Towards Drugs                 -0.081309                  0.191474
# Social Connections                      0.125481                 -0.150156
# Past Failures                           0.003573                  0.117247
# Suicidal Thoughts                       0.090755                  0.077028
# Family Relationships                    0.019963                 -0.014246
# Family Finances                        -0.194267                  0.090224
# Addicted Friends                       -0.011541                  0.197653
# Family Addiction                        0.223463                 -0.012116
# Workplace Satisfaction                  0.035053                 -0.248708
# Legal Cases                            -0.127849                  0.180908
# Living with Drug User                  -0.024684                  0.334360
# Drug Use Factors                       -0.045971                 -0.018290
# Past Drug Use                          -0.117099                  0.281511
# First Drug Name                         0.001904                 -0.139478
# First Drug Age                         -0.003701                  0.094979
# Frequency of Drug Use                   0.307241                 -0.090762
# Current Drug Use                        0.004748                  0.071632
# Occasions for Drug Use                  1.000000                 -0.172489
# Willingness to Try Drugs               -0.172489                  1.000000
# Drug Control                           -0.197468                  0.070502
# Reasons for Starting                    0.074689                  0.072291
# Guilt After Drug Use                    0.026258                 -0.236381
#
#                           Drug Control  Reasons for Starting  \
# Age                           0.256922              0.045406
# Gender                       -0.095941              0.223935
# Education                     0.175407              0.041937
# Living Situation              0.161964             -0.035533
# Attitude Towards Drugs       -0.010777             -0.048492
# Social Connections            0.014722              0.104376
# Past Failures                 0.038526              0.077515
# Suicidal Thoughts            -0.037575              0.003484
# Family Relationships          0.063505              0.094430
# Family Finances              -0.080656              0.116053
# Addicted Friends             -0.036713             -0.204221
# Family Addiction              0.110481             -0.035604
# Workplace Satisfaction        0.062994             -0.118639
# Legal Cases                  -0.174122             -0.044012
# Living with Drug User         0.104852              0.109066
# Drug Use Factors             -0.176729              0.220602
# Past Drug Use                -0.064687              0.549553
# First Drug Name              -0.022754              0.018630
# First Drug Age                0.081553              0.042442
# Frequency of Drug Use        -0.093438              0.014693
# Current Drug Use              0.040195             -0.381486
# Occasions for Drug Use       -0.197468              0.074689
# Willingness to Try Drugs      0.070502              0.072291
# Drug Control                  1.000000              0.007773
# Reasons for Starting          0.007773              1.000000
# Guilt After Drug Use          0.066066             -0.306472
#
#                           Guilt After Drug Use
# Age                                   0.076588
# Gender                               -0.143921
# Education                             0.172910
# Living Situation                     -0.033448
# Attitude Towards Drugs               -0.248493
# Social Connections                    0.038723
# Past Failures                        -0.026725
# Suicidal Thoughts                     0.003008
# Family Relationships                 -0.038296
# Family Finances                      -0.104906
# Addicted Friends                      0.022139
# Family Addiction                     -0.003193
# Workplace Satisfaction                0.131095
# Legal Cases                          -0.500626
# Living with Drug User                -0.032521
# Drug Use Factors                      0.013382
# Past Drug Use                        -0.330425
# First Drug Name                       0.271337
# First Drug Age                       -0.143804
# Frequency of Drug Use                 0.082564
# Current Drug Use                      0.169183
# Occasions for Drug Use                0.026258
# Willingness to Try Drugs             -0.236381
# Drug Control                          0.066066
# Reasons for Starting                 -0.306472
# Guilt After Drug Use                  1.000000
#
# [26 rows x 26 columns]

# %%
plt.figure(figsize=(18,15))
sns.heatmap(df.corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Separate numeric and categorical columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical columns (you can choose a different encoding method)
encoder = LabelEncoder()
for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

# Separate your features (X) and target variable (y)
X_numeric = df[numeric_columns].drop(columns=['Guilt After Drug Use'])  # Exclude the target column
y = df['Guilt After Drug Use']

# Apply feature selection using chi-squared (for classification tasks)
selector = SelectKBest(score_func=chi2, k=5)  # Select the top 5 features

# Fit the selector to your numeric data and transform the features
X_numeric_new = selector.fit_transform(X_numeric, y)

# Get the indices of the selected features
selected_indices = selector.get_support(indices=True)

# Print the names of the selected features
selected_features = X_numeric.columns[selected_indices]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Attitude Towards Drugs', 'Legal Cases', 'Past Drug Use',
#        'Current Drug Use', 'Reasons for Starting'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Splitting the selected numeric features and the target variable (y) into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting datasets to verify the split
print("Training data shape (X_train, y_train):", X_train.shape, y_train.shape)
print("Testing data shape (X_test, y_test):", X_test.shape, y_test.shape)
# Out:
# Training data shape (X_train, y_train): (55, 5) (55,)
# Testing data shape (X_test, y_test): (14, 5) (14,)

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy
accuracy = np.sum(y_pred == y_test) / len(y_test)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8571428571428571

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
import matplotlib.pyplot as plt


# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Naive Bayes Classifier")
plt.show()

# %%
from sklearn.metrics import classification_report

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.86        14
#    macro avg       0.46      0.46      0.46        14
# weighted avg       0.86      0.86      0.86        14

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.naive_bayes import GaussianNB

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the Naive Bayes model
model = GaussianNB()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict_proba(X_test)[:, 1]

# Reshape the predicted values into a 2D array
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the decision tree classifier
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)


# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8571428571428571
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.50      1.00      0.67         1
#            2       1.00      0.85      0.92        13
#
#     accuracy                           0.86        14
#    macro avg       0.50      0.62      0.53        14
# weighted avg       0.96      0.86      0.90        14

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data


# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Generate the confusion matrix graph
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Decision Tree Classifier")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the decision tree model
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7857142857142857

# %%
from sklearn.metrics import classification_report

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         1
#            2       1.00      0.85      0.92        13
#
#     accuracy                           0.79        14
#    macro avg       0.33      0.28      0.31        14
# weighted avg       0.93      0.79      0.85        14

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt



# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for KNN Classifier")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the KNN model
model = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = y_pred[:, np.newaxis]

# Create a heatmap of the predicted values
sns.heatmap(y_pred, annot=True, fmt=".3f", cmap="viridis")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted values")
plt.ylabel("Test data instances")

# Add a title to the heatmap
plt.title("Heatmap of predicted values")

# Display the heatmap
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Print the accuracy
accuracy = np.sum(y_pred == y_test) / len(y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8571428571428571

# %%
from sklearn.metrics import classification_report

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Generate a classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.86        14
#    macro avg       0.46      0.46      0.46        14
# weighted avg       0.86      0.86      0.86        14

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the logistic regression model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred_proba = model.predict_proba(X_test)

# Create a heatmap of the predicted probabilities
sns.heatmap(y_pred_proba, annot=True, fmt=".3f")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted probability of class 1")
plt.ylabel("Actual class")

# Add a title to the heatmap
plt.title("Heatmap of predicted probabilities")

# Display the heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt



# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Compute the confusion matrix
cm = np.array(pd.crosstab(y_test, y_pred))

# Generate the heatmap
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Logistic Regression Classifier")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the MAE, MSE, and R^2
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the MAE, MSE, and R^2
print("MAE:", mae)
print("MSE:", mse)
print("R^2:", r2)
# Out:
# MAE: 0.227905856650213
# MSE: 0.09471544911663178
# R^2: -0.4280175405276796

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.2, random_state=42)

# Create a machine learning model
# ...

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the confusion matrix

# Plot the confusion matrix as a heatmap
sns.heatmap(cm, annot=True, fmt=".0f")

# Add labels to the x- and y-axes of the heatmap
plt.xlabel("Predicted")
plt.ylabel("Actual")

# Add a title to the heatmap
plt.title("Confusion Matrix of Linear Regression")

# Display the heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data


# Fit the model to the training data
model.fit(X_train, y_train)

# Get the linear regression coefficients
coefs = model.coef_

# Generate a heatmap of the linear regression coefficients
sns.heatmap(coefs.reshape(1, -1), annot=True, fmt=".2f")
plt.xlabel("Features")
plt.ylabel("Linear Regression Coefficients")
plt.title("Heatmap of Linear Regression Coefficients")
plt.show()
